# %% [markdown]
# # Structure of Materials

# %% [markdown]
# #
# ## Section 5

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Cu = $4s^2 3d^9$
#
# - Pd = $5s^2 4d^8$
#
# - Ag = $5s^2 4d^{9}$
#
# - Au = $6s^2 4f^{14} 5d^{9}$
#
#
# What should the electron conﬁgurations be if these elements followed Madelung’s rule and the Aufbau principle?

# %% [markdown]
# ### Section 6
#
# ![image.png](attachment:image.png)

# %%
## Section
